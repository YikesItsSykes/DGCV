# %%
from dgcv import *

# %%
createSimpleLieAlgebra('A3')

# %%
sl4.multiplication_table(generate_full_report=True,theme='quilt_gingham_red')
# Out:
# <div id="dgcv-view-6bdd508c"><style>
#             #dgcv-view-6bdd508c {
#     --dgcv-bg-primary: #fdfbf6;
#     --dgcv-text-main: #3a1414;
#     --dgcv-bg-surface: #f9efe9;
#     --dgcv-text-heading: #a3242a;
#     --dgcv-bg-alt: #fdf5f1;
#     --dgcv-bg-hover: #f3cfca;
#     --dgcv-text-hover: #3a1414;
#     --dgcv-bg-action: #a81f22;
#     --dgcv-text-on-action: #ffffff;
#     --dgcv-bg-action-hover: #bd3033;
#     --dgcv-bg-error: #8f1a20;
#     --dgcv-text-on-error: #ffffff;
#     --dgcv-bg-success: #2f7d4f;
#     --dgcv-text-on-success: #ffffff;
#     --dgcv-border-main: #e3c2bd;
#     --dgcv-border-alt: #efd9d5;
#     --dgcv-font-family: Georgia, serif;
#     --dgcv-text-alt: #6e4642;
#     --dgcv-border-width: 1px;
#     --dgcv-special-text: #2a0d0d;
#     --dgcv-special-background: repeating-linear-gradient(90deg, rgba(198, 40, 40, 0.62) 0 9px, transparent 9px 18px), repeating-linear-gradient(0deg, rgba(198, 40, 40, 0.62) 0 9px, transparent 9px 18px), #fcfaf5;
# ...

# %%
sl4.summary(generate_full_report=True,theme='quilt_kagome_dark')
# Out:
# <dgcv.algebras.algebras_core._summary_render_rich.<locals>._HTMLWrapper at 0x10afedfd0>
